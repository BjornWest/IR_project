# %%
import gdown
import os
embeddings_id = '1ELlMv4qglFxTFZfoXXAyf7sAxRGwqSe7'
matrices_id = '1JXVZwMlnkj6R15PULxsQJec2cHP5dgzI'

path = os.getcwd()


text_with_metadata_output = os.path.join(path, "/data/embeddings.npy")
tweets_data_output = os.path.join(path, "/data/matrices.npy")

output =  # modify 
file_id =  # modify 
url = f'https://drive.google.com/uc?id={file_id}'
gdown.download(url, output, quiet=False)

# %%
import os
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

folder_id = "1klVZmp55-w74s6Yf4JVaZUf99dT7FNW1"
file_name = "embeddings.npy"
client_config = "/root/drive_config.json"

gauth = GoogleAuth()
gauth.LoadClientConfigFile(client_config)
gauth.LocalWebserverAuth()  # will print a URL -> approve -> paste code back
drive = GoogleDrive(gauth)

file_path = os.path.join(os.getcwd(), "data", file_name)
gfile = drive.CreateFile({"parents": [{"id": folder_id}], "title": file_name})
gfile.SetContentFile(file_path)
gfile.Upload()
print("Uploaded", file_path)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=837586148859-5qcjrqevf6jfonv9g4dte7qbik47l73q.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=online&response_type=code
#
# Authentication successful.
# Uploaded /root/IR_project/actually_important/data/embeddings.npy
